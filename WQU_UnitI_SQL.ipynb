# %%
# %load_ext sql
# %sql sqlite:///testdb.sqlite
# Out:
# 'Connected: @testdb.sqlite'

# %%
# %%sql
# -- The sql magic makes this cell as sql
#
#
# -- Getting ride of the tables if they exist
# DROP TABLE IF EXISTS customers;
# DROP TABLE IF EXISTS products;
# DROP TABLE IF EXISTS orders;
#
# -- Creating the Tables
# CREATE TABLE customers(
#   id                    INTEGER PRIMARY KEY NOT NULL,
#   name                  TEXT NOT NULL,
#   billing_address       TEXT NOT NULL
#
# );
#
#
# CREATE TABLE products(
#   id                    INTEGER PRIMARY KEY NOT NULL,
#   price                 NUMBER NOT NULL
#
# );
#
# CREATE TABLE orders(
#   id                    INTEGER NOT NULL,
#   customer_id           NUMBER,
#   product_id            NUMBER,
#   delivery_address      TEXT NOT NULL,
#   FOREIGN KEY(customer_id) REFERENCES customers(id),
#   FOREIGN KEY(product_id) REFERENCES products(id)
#
# );
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
#
# DROP TABLE IF EXISTS Students_Data;
# -- Creating The Table Architecture
#
# CREATE TABLE Students_Data(
#   Stud_ID                INTEGER PRIMARY KEY NOT NULL,
#   Fname                  TEXT NOT NULL,
#   Lname                  TEXT NOT NULL,
#   Sex                    CHAR NOT NULL,
#   DateofBirth            DATE NOT NULL,
#   Country                TEXT NOT NULL,
#   Department             TEXT NOT NULL,
#   Faculty                TEXT NOT NULL
# );
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# Done.
# []

# %%
# %%sql
#
# -- Inserting the Values
#
#
# INSERT INTO Students_Data(Stud_ID, Fname, Lname, Sex, DateofBirth, Country, Department, Faculty)
#   VALUES (111, 'ALbert','Ansim', 'F','79-11-11', 'Uganda', 'Management', 'ENGINEERING'),
#          (130, 'Manzi','Kadafi', 'M','80-11-11', 'Burundi', 'Statistic', 'SCIENCE'),
#          (132, 'Luc','Kadafi', 'M','80-11-11', 'Burundi', 'Computer Science', 'SCIENCE'),
#          (131, 'Manzi','John', 'M','80-11-11', 'Burundi', 'Computer Science', 'SCIENCE'),
#          (140, 'Bienve','Paul', 'M','87-11-11', 'Tanzani', 'Management', 'FSEG'),
#          (145, 'Bienve','Rosario', 'F','77-11-11', 'DRC', 'Computer Science', 'FSEG'),
#          (150, 'Bienve','Anse', 'F','74-11-11', 'Rwanda', 'Statistic', 'FSEG'),
#          (155, 'Bienve','Shabab', 'F','75-11-11', 'Rwanda', 'Management', 'ENGINEERING'),
#          (156, 'Bienve','Shabab', 'M','85-11-11', 'Tanzani', 'Computer Science', 'SCIENCE'),
#          (160, 'Bienve','Shabab', 'F','79-11-11', 'Tanzani', 'Statistic', 'ENGINEERING');
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# []

# %%
# %%sql
#
# select * from Students_Data;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(111, 'ALbert', 'Ansim', 'F', '79-11-11', 'Uganda', 'Management', 'ENGINEERING'),
#  (130, 'Manzi', 'Kadafi', 'M', '80-11-11', 'Burundi', 'Statistic', 'SCIENCE'),
#  (131, 'Manzi', 'John', 'M', '80-11-11', 'Burundi', 'Computer Science', 'SCIENCE'),
#  (132, 'Luc', 'Kadafi', 'M', '80-11-11', 'Burundi', 'Computer Science', 'SCIENCE'),
#  (140, 'Bienve', 'Paul', 'M', '87-11-11', 'Tanzani', 'Management', 'FSEG'),
#  (145, 'Bienve', 'Rosario', 'F', '77-11-11', 'DRC', 'Computer Science', 'FSEG'),
#  (150, 'Bienve', 'Anse', 'F', '74-11-11', 'Rwanda', 'Statistic', 'FSEG'),
#  (155, 'Bienve', 'Shabab', 'F', '75-11-11', 'Rwanda', 'Management', 'ENGINEERING'),
#  (156, 'Bienve', 'Shabab', 'M', '85-11-11', 'Tanzani', 'Computer Science', 'SCIENCE'),
#  (160, 'Bienve', 'Shabab', 'F', '79-11-11', 'Tanzani', 'Statistic', 'ENGINEERING')]

# %%
# %%sql
#
#
# --All male students from Rwanda doing computer science sorted in ascending order using their fname.
#
# SELECT *
# FROM Students_Data
# WHERE Sex='M' AND Department='Computer Science'
# ORDER BY Fname ASC;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(156, 'Bienve', 'Shabab', 'M', '85-11-11', 'Tanzani', 'Computer Science', 'SCIENCE'),
#  (132, 'Luc', 'Kadafi', 'M', '80-11-11', 'Burundi', 'Computer Science', 'SCIENCE'),
#  (131, 'Manzi', 'John', 'M', '80-11-11', 'Burundi', 'Computer Science', 'SCIENCE')]

# %%
# %%sql
#
# -- All female students from Rwanda in a faculty of FSEG sorted in ascending order using their stud_ID.
#
# SELECT *
# FROM Students_Data
# WHERE Country='Rwanda' AND Faculty='FSEG'
# ORDER BY Stud_ID ASC;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(150, 'Bienve', 'Anse', 'F', '74-11-11', 'Rwanda', 'Statistic', 'FSEG')]

# %%
# %%sql
#
# -- All students doing statistics arranged in ascending order using their Lname.
# SELECT *
# FROM Students_Data
# WHERE Department='Statistic'
# ORDER BY Lname ASC;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(150, 'Bienve', 'Anse', 'F', '74-11-11', 'Rwanda', 'Statistic', 'FSEG'),
#  (130, 'Manzi', 'Kadafi', 'M', '80-11-11', 'Burundi', 'Statistic', 'SCIENCE'),
#  (101, 'Bienve', 'Shabab', 'M', '76-11-11', 'Tanzani', 'Statistic', 'SCIENCE'),
#  (160, 'Bienve', 'Shabab', 'F', '79-11-11', 'Tanzani', 'Statistic', 'ENGINEERING')]

# %%
# %%sql
#
# --All students from Burundi arranged in their respective department.
#
# SELECT *
# FROM Students_Data
# WHERE Country='Burundi'
# ORDER BY Department;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(130, 'Manzi', 'Kadafi', 'M', '80-11-11', 'Burundi', 'Statistic', 'SCIENCE')]

# %%
# %%sql
#
# --All students who were born in the year 75 and 76.
# SELECT *
# FROM Students_Data
# WHERE DateofBirth BETWEEN '75-11-11' AND '76-11-11';
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(155, 'Bienve', 'Shabab', 'F', '75-11-11', 'Rwanda', 'Management', 'ENGINEERING')]

# %%
# %%sql
#
# SELECT *
# FROM orders;

# %%
# %%sql
#
# -- Inserting some data in tables
#
# INSERT INTO customers(id, name, billing_address)
#   VALUES (435, 'Omar', 'Berlin Germany'), (467, 'Steve', 'Dover UK'),
#          (6527, 'Vicky', 'Dover UK'), (6129, 'Alex', 'Mumbai India'),
#          (6027, 'Jane', 'Mumbai India'), (6128, 'Ndapile', 'Lilongwe Malawi'),
#          (297, 'Anker', 'Berlin Germany'), (6117, 'Vicky', 'Accra Ghana'),
#          (127, 'Victory', 'Mumbai India'), (6137, 'Vicky', 'Paris France'),
#          (61, 'Paul', 'Berlin Germany'), (617, 'Vicky', 'Berlin Germany');
#
# INSERT INTO products (id, price)
#   VALUES (103, 57.8), (576, 98), (957, 23.8), (456, 784.5), (467, 58.3), (462, 578.3),
#          (13, 17.8), (56, 198), (97, 203.8), (45, 7804.5), (47, 5809.3), (461, 5558.3);
#
# INSERT INTO orders (id, delivery_address)
#   VALUES (6073, 'Dover, UK'), (7289, 'Tunis, Tunisia'),
#          (5631, 'Dover, UK'), (7290, 'Accra Ghana'),
#          (5613, 'Accra Ghana'), (7129, 'Tunis, Tunisia'),
#          (5730, 'Accra Ghana'), (7819, 'Tunis, Tunisia'),
#          (5173, 'Dover, UK'), (7890, 'Accra Ghana'),
#          (5673, 'Dover, UK'), (7291, 'Tunis, Tunisia');
#
# INSERT INTO orders (id, delivery_address)
#   VALUES (37458, 'Berlin Germany'), (3893, 'Dover, UK'),
#           (37457, 'Berlin Germany'), (3896, 'Dover, UK'),
#           (37456, 'Berlin Germany'), (3895, 'Dover, UK'),
#           (37455, 'Berlin Germany'), (3894, 'Dover, UK'),
#           (37454, 'Berlin Germany'), (3892, 'Dover, UK'),
#           (37453, 'Berlin Germany'), (3831, 'Dover, UK');
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# 12 rows affected.
# 12 rows affected.
# 12 rows affected.
# []

# %%
# %%sql
#
# SELECT *
# FROM orders
# LIMIT(5);
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(6073, None, None, 'Dover, UK'),
#  (7289, None, None, 'Tunis, Tunisia'),
#  (5631, None, None, 'Dover, UK'),
#  (7290, None, None, 'Accra Ghana'),
#  (5613, None, None, 'Accra Ghana')]

# %%
# %%sql
#
# SELECT *
# FROM customers;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(435, 'Omar', 'Berlin Germany'),
#  (467, 'Steve', 'Dover UK'),
#  (6127, 'Vicky', 'Mumbai India')]

# %%
# %%sql
#
# SELECT * FROM orders
#   LIMIT 2
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(5673, 435, 675, 'Dover, UK'), (7289, 435, 128, 'Tunis, Tunisia')]

# %%
# %%sql
#
# SELECT *
# FROM products LIMIT 2;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(103, 57.8), (456, 784.5)]

# %%
#Loading data from CSV file to SQL tables
#With Panadas and SqlLite
import pandas as pd
import sqlite3

conn = sqlite3.connect('testdb.sqlite')
customers = pd.read_csv('/content/drive/MyDrive/worldquant/Unit I/data/customers.csv')
products = pd.read_csv('/content/drive/MyDrive/worldquant/Unit I/data/products.csv')
orders = pd.read_csv('/content/drive/MyDrive/worldquant/Unit I/data/orders.csv')

customers.to_sql('customers', conn, index=False, if_exists='replace' )
products.to_sql('products', conn, index=False, if_exists='replace')
orders.to_sql('orders', conn, index=False, if_exists='replace')

# %%
products.shape, customers.shape, orders.shape
# Out:
# ((1000, 2), (519, 3), (2000, 4))

# %%
# %%sql
#
# SELECT *
# FROM customers
# LIMIT 2;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(1, 'Serenity Ladner', 'Canada'), (2, 'Lucy Baldwin', 'Canada')]

# %%
# %%sql
#
# SELECT *
# FROM orders LIMIT 5;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(0, 1866, 686, 'India'),
#  (1, 1921, 617, 'China'),
#  (1, 1921, 54, 'Armenia'),
#  (1, 1921, 566, 'China'),
#  (1, 1921, 128, 'Lebanon')]

# %%
# %%sql
#
# SELECT *
# FROM products LIMIT 2
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(0, 21.78), (1, 18.48)]

# %%
# %%sql
#
# -- Filtering and storing data
#
# SELECT id, delivery_country
# FROM orders
# WHERE delivery_country = 'India'
# LIMIT 10;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(0, 'India'),
#  (60, 'India'),
#  (60, 'India'),
#  (60, 'India'),
#  (64, 'India'),
#  (66, 'India'),
#  (66, 'India'),
#  (68, 'India'),
#  (103, 'India'),
#  (103, 'India')]

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE price >= 20
# ORDER BY PRICE DESC
# LIMIT 10;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(381, 39.91),
#  (584, 38.42),
#  (367, 37.76),
#  (311, 37.67),
#  (488, 36.72),
#  (641, 36.69),
#  (291, 36.39),
#  (215, 36.34),
#  (748, 35.91),
#  (897, 35.71)]

# %%
# %%sql
# -- Pattern recognition
#
# SELECT id, delivery_country
# FROM orders
# WHERE delivery_country LIKE '_S%'
# LIMIT 10;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(7, 'USA'),
#  (84, 'Estonia'),
#  (86, 'USA'),
#  (130, 'Estonia'),
#  (141, 'USA'),
#  (141, 'USA'),
#  (141, 'USA'),
#  (146, 'USA'),
#  (146, 'USA'),
#  (146, 'USA')]

# %%
# %%sql
#
# SELECT *
# FROM orders
# WHERE customer_id IN (400, 10) ;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(542, 400, 80, 'Sweden'),
#  (542, 400, 405, 'Sweden'),
#  (818, 10, 778, 'Canada'),
#  (818, 10, 60, 'Canada')]

# %%
# %%sql
#
# SELECT * FROM orders
# WHERE customer_id IN (200, 400, 800)
# AND delivery_country NOT IN ('Madagascar', 'Canada');
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(211, 200, 434, 'Mexico'),
#  (542, 400, 80, 'Sweden'),
#  (542, 400, 405, 'Sweden')]

# %%
# %%sql
#
# --Sorting data
#
# SELECT *
# FROM orders
# ORDER BY customer_id ASC, product_id DESC
# LIMIT 6;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(949, 1, 592, 'Canada'),
#  (189, 1, 508, 'Poland'),
#  (949, 1, 431, 'Canada'),
#  (189, 1, 307, 'Canada'),
#  (146, 5, 864, 'USA'),
#  (146, 5, 688, 'USA')]

# %%
# %%sql
#
# -- Performing Data aggregation
#
# SELECT AVG(price) average, MAX(price) maximum, MIN(price) minimum, SUM(PRICE) total
# FROM products;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(19.98996999999997, 39.91, 5.8, 19989.969999999972)]

# %%
#as similar in Pandas
products['price'].agg({'mean', 'max'})
# Out:
# max     39.91000
# mean    19.98997
# Name: price, dtype: float64

# %%
# %%sql
#
# SELECT delivery_country country, COUNT(DISTINCT(id)) AS count
# FROM orders
# GROUP BY delivery_country
# ORDER BY count DESC
# LIMIT 10;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [('China', 60),
#  ('India', 60),
#  ('Germany', 59),
#  ('Russia', 42),
#  ('Japan', 37),
#  ('South Korea', 37),
#  ('Spain', 36),
#  ('USA', 36),
#  ('Canada', 35),
#  ('France', 31)]

# %%
# %%sql
#
# --Joining Tables together
#
# SELECT SUM(p.price) total
# FROM orders o
# JOIN products p
# ON (o.product_id = p.id);
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(39988.80999999999,)]

# %%
# %%sql
#
# -- Similarly, can select from more tables
#
# SELECT SUM(p.price)
# FROM orders o, products p
# WHERE p.id = o.product_id;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(39988.80999999999,)]

# %%
# %%sql
#
# -- Joins combined with aggregations
#
# SELECT c.name, SUM(p.price) total
# FROM orders o, products p, customers c
# WHERE p.id = o.product_id AND c.id = o.customer_id
# GROUP BY c.id
# ORDER BY total DESC
# LIMIT 10;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [('Sevil Caker', 315.09),
#  ('Pons Baluze', 306.84999999999997),
#  ('Boikai Owiti', 297.10999999999996),
#  ('Ahmed Onyango', 291.38000000000005),
#  ('Bui Tuan', 274.92),
#  ('Seth Bowden', 270.44),
#  ('Sandra Lakatos', 267.04),
#  ('Jonas Papp', 265.48),
#  ('Kristina Hovath', 263.03999999999996),
#  ('Vasha Nwosu', 260.15000000000003)]

# %%
# %%sql
#
# -- Working with a subquery and aggregation
# SELECT shp.bill, SUM(shp.rev) spent
# FROM (SELECT c.billing_country bill, o.delivery_country deliver, SUM(p.price) rev
#       FROM orders o, customers c, products p
#       WHERE o.customer_id = c.id AND o.product_id = p.id
#       GROUP BY bill, deliver
#       HAVING bill != deliver) shp
# GROUP BY shp.bill
# ORDER BY spent DESC
# LIMIT 10;
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [('Germany', 751.0099999999999),
#  ('China', 684.0699999999999),
#  ('India', 678.2499999999998),
#  ('USA', 442.76000000000005),
#  ('Russia', 397.93),
#  ('Japan', 373.27),
#  ('South Korea', 354.81999999999994),
#  ('Italy', 343.0799999999999),
#  ('France', 287.71),
#  ('Canada', 237.47000000000003)]

# %%
# %%sql
#
# SELECT c.billing_country bill, o.delivery_country deliver, SUM(p.price) rev
#       FROM orders o, customers c, products p
#       WHERE o.customer_id = c.id AND o.product_id = p.id
#       GROUP BY bill, deliver
#       HAVING bill != deliver
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [('Algeria', 'Germany', 18.57),
#  ('Algeria', 'Guinea', 24.97),
#  ('Algeria', 'India', 32.4),
#  ('Algeria', 'Moldova', 20.42),
#  ('Algeria', 'Montenegro', 16.06),
#  ('Algeria', 'Moxambique', 19.14),
#  ('Algeria', 'Poland', 24.93),
#  ('Angola', 'Kuwait', 9.82),
#  ('Angola', 'Serbia', 12.02),
#  ('Austria', 'Malawi', 28.92),
#  ('Bahrain', 'Egypt', 21.59),
#  ('Belarus', 'Benin', 20.06),
#  ('Belarus', 'Cameroon', 23.99),
#  ('Benin', 'Belarus', 27.75),
#  ('Benin', 'Norway', 28.34),
#  ('Cameroon', 'Austria', 33.24),
#  ('Cameroon', 'Eritrea', 20.97),
#  ('Cameroon', 'Macedonia', 29.66),
#  ('Cameroon', 'Norway', 17.0),
#  ('Cameroon', 'Zimbabwe', 21.4),
#  ('Canada', 'Albania', 28.89),
#  ('Canada', 'Belarus', 14.08),
#  ('Canada', 'Czech Republic', 19.35),
#  ('Canada', 'Egypt', 28.48),
#  ('Canada', 'Moldova', 17.53),
#  ('Canada', 'Montenegro', 24.07),
#  ('Canada', 'Poland', 19.55),
#  ('Canada', 'Slovenia', 26.7),
# ...

# %%
# %%sql
#
# SELECT COUNT(*) all_ FROM products
# Out:
#  * sqlite:///testdb.sqlite
# Done.
# [(1000,)]
